# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline 
import pandas as pd
import json
from tqdm import tqdm

import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/kirthanpakki/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kirthanpakki/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/kirthanpakki/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Preprocessing Businesses Dataset

# %%
biz_df = pd.read_json('yelp_dataset/yelp_academic_dataset_business.json', lines = True)
biz_df.head()
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                               None
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %%
biz_df.shape
# Out:
# (150346, 14)

# %%
biz_df['is_open'].value_counts()
# Out:
# 1    119698
# 0     30648
# Name: is_open, dtype: int64

# %%
# Dropping any businesses which are closed
biz_df = biz_df[biz_df['is_open'] == 1]

# %%
biz_df.shape
# Out:
# (119698, 14)

# %% [markdown]
# ### Filtering out Businesses which are not Food

# %%
# Getting all the various categories in the dataset

all_categories = biz_df['categories'].str.split(', ').explode()
all_categories = set(all_categories)

# %%
len(all_categories)
# Out:
# 1303

# %%
print(all_categories)
# Out:
# {'Consumer Law', 'Department Stores', 'Casinos', 'General Litigation', 'Bird Shops', 'Gastropubs', 'Digitizing Services', 'Television Service Providers', 'Home Decor', 'Head Shops', 'Framing', 'Beverage Store', 'Bicycle Paths', 'Bespoke Clothing', 'Senior Centers', 'Marinas', 'Process Servers', 'Physical Therapy', 'Swimming Pools', 'Smokehouse', 'Valet Services', 'Service Stations', 'Business Law', 'Estheticians', 'Pediatric Dentists', 'Radiologists', 'Limos', 'Ice Cream & Frozen Yogurt', 'Optometrists', 'Elder Law', 'Delis', 'Candle Stores', 'Beer Bar', 'Shopping Centers', 'Lebanese', 'Sushi Bars', 'Ethnic Grocery', 'Shoe Stores', 'Cannabis Clinics', 'Interval Training Gyms', 'Sandblasting', 'Fuzhou', 'Irrigation', 'Vape Shops', 'Diners', 'Cannabis Collective', 'Batting Cages', 'Professional Services', 'Skating Rinks', 'Cosmetic Dentists', 'Wigs', 'Urologists', 'Home & Garden', 'Indian', 'Food', 'Salad', 'Rodeo', 'Golf Cart Rentals', 'Bikes', 'Courthouses', 'Estate Planning Law', 'Childproofing', 'Electricians', 'Tableware', 'Home Health Care', 'Outdoor Furniture Stores', 'Veterans Organizations', 'Ceremonial Clothing', 'Auto Insurance', 'Real Estate Services', 'Permanent Makeup', 'Carpet Installation', 'Debt Relief Services', 'Southern', 'Audiologist', 'Education', 'Climbing', 'Karaoke Rental', 'Pets', 'Pasta Shops', 'Airlines', 'Patisserie/Cake Shop', 'Excavation Services', 'Machine Shops', 'Accountants', 'Gutter Services', 'Sheds & Outdoor Storage', 'Cycling Classes', 'Vacation Rentals', 'Halotherapy', 'Car Stereo Installation', 'Pakistani', 'Holiday Decorating Services', 'Flyboarding', 'Oil Change Stations', 'International', 'Bike Sharing', 'Trailer Dealers', 'Races & Competitions', 'Nanny Services', 'Gold Buyers', 'Scandinavian', 'Boot Camps', 'Skilled Nursing', 'Traditional Clothing', 'Sex Therapists', 'Roofing', 'Trivia Hosts', 'Grocery', 'Orthodontists', 'Haunted Houses', 'Zoos', 'Rugs', 'Podiatrists', 'Cardio Classes', 'Shredding Services', 'Hotels', 'Poke', 'Notaries', 'Hot Air Balloons', 'Weight Loss Centers', 'American (Traditional)', 'Brewpubs', 'Fuel Docks', 'Ethical Grocery', 'Fondue', 'Blood & Plasma Donation Centers', 'Commercial Truck Repair', "Children's Clothing", 'ATV Rentals/Tours', 'Trains', 'Foot Care', 'Gluten-Free', 'Urgent Care', 'Beauty & Spas', 'Racing Experience', 'Crane Services', 'Tubing', 'Bus Tours', 'Reptile Shops', 'Fitness & Instruction', 'Car Buyers', 'Medical Centers', 'Cremation Services', 'Candy Stores', 'Architects', 'Boat Dealers', 'Jewelry Repair', 'Badminton', 'Diamond Buyers', 'Aerial Tours', 'Prosthetics', 'Naturopathic/Holistic', 'Skin Care', 'Embassy', 'Proctologists', 'Mailbox Centers', 'Town Hall', 'Hydroponics', 'Shipping Centers', 'Mags', 'Nightlife', 'Community Centers', 'Paint-Your-Own Pottery', 'Bike tours', 'Vocational & Technical School', 'Aircraft Repairs', 'Family Practice', 'Taiwanese', 'Food Trucks', 'Greek', 'Cocktail Bars', 'Cardiologists', 'Argentine', 'Leather Goods', 'Plastic Surgeons', 'Insurance', 'Tiling', 'Scuba Diving', 'Performing Arts', 'Drugstores', 'Hockey Equipment', 'Land Surveying', 'Gastroenterologist', 'Car Auctions', 'Convenience Stores', 'Oriental', 'Well Drilling', 'Wills', 'Medical Transportation', 'Screen Printing', 'Burgers', 'Internet Service Providers', 'Donairs', 'Buses', 'Game Truck Rental', 'Artificial Turf', 'Amateur Sports Teams', 'Beach Equipment Rentals', 'Formal Wear', 'Tex-Mex', 'Guamanian', 'Oncologist', 'Latin American', 'Baseball Fields', 'Business Consulting', 'Active Life', 'Financial Services', 'Mobile Home Repair', 'Eastern European', 'Fabric Stores', 'Dental Hygienists', 'Title Loans', 'Japanese Curry', 'Art Museums', 'Environmental Testing', 'Indoor Landscaping', 'Australian', 'General Dentistry', 'Buddhist Temples', 'Nail Technicians', 'Reflexology', 'Vintage & Consignment', 'Shopping', 'Mobile Phones', 'Web Design', 'Neurotologists', 'Bookbinding', 'Pet Groomers', 'Bus Rental', 'Poutineries', 'Canadian (New)', 'Mobile  ...

# %%
food_categories = {
    'Beverage Store',
    'Department Stores',
    'Smokehouse',
    'Valet Services',
    'Ice Cream & Frozen Yogurt',
    'Delis',
    'Beer Bar',
    'Sushi Bars',
    'Diners',
    'Indian',
    'Food',
    'Salad',
    'Southern',
    'Pasta Shops',
    'Patisserie/Cake Shop',
    'Pakistani',
    'Scandinavian',
    'Hotels',
    'American (Traditional)',
    'Fondue',
    'Gluten-Free',
    'Candy Stores',
    'Nightlife',
    'Taiwanese',
    'Food Trucks',
    'Greek',
    'Cocktail Bars',
    'Burgers',
    'Donairs',
    'Tex-Mex',
    'Guamanian',
    'Latin American',
    'Eastern European',
    'Japanese Curry',
    'Poutineries',
    'Canadian (New)',
    'Steakhouses',
    'Noodles',
    'Coffee & Tea Supplies',
    'Themed Cafes',
    'Uzbek',
    'Breakfast & Brunch',
    'Soup',
    'Mongolian',
    'Food Tours',
    'Shanghainese',
    'Drive-In Theater',
    'Cambodian',
    'Delicatessen',
    'Wineries',
    'Spanish',
    'Speakeasies',
    'Meaderies',
    'Turkish',
    'Comfort Food',
    'Whiskey Bars',
    'Dance Clubs',
    'Vegetarian',
    'Food Delivery Services',
    'Live/Raw Food',
    'Tacos',
    'Afghan',
    'Sandwiches',
    'Coffeeshops',
    'Food Court',
    'Hungarian',
    'Persian/Iranian',
    'Japanese',
    'Szechuan',
    'American (New)',
    'Pita',
    'Brazilian',
    'Custom Cakes',
    'Buffets',
    'Cabaret',
    'Bagels',
    'Bowling',
    'Sri Lankan',
    'Bakeries',
    'Restaurants',
    'Belgian',
    'Peruvian',
    'Breweries',
    'Bars',
    'Coffee Roasteries',
    'Food Banks',
    'Pubs',
    'Shaved Ice',
    'Conveyor Belt Sushi',
    'Wraps',
    'Malaysian',
    'Syrian',
    'Olive Oil',
    'Ethiopian',
    'Calabrian',
    'Italian',
    'Cucina campana',
    'Cheese Shops',
    'Puerto Rican',
    'New Mexican Cuisine',
    'Beer Gardens',
    'Wine Tasting Room',
    'Pan Asian',
    'Cuban',
    'Colombian',
    'Venezuelan',
    'Chicken Wings',
    'Himalayan/Nepalese',
    'Donuts',
    'Karaoke',
    'Fast Food',
    'Ukrainian',
    'Senegalese',
    'Donburi',
    'Popcorn Shops',
    'Somali',
    'Burmese',
    'Tai Chi',
    'Juice Bars & Smoothies',
    'Vietnamese',
    'Mediterranean',
    'Hawaiian',
    'South African',
    'Hakka',
    'Modern European',
    'Creperies',
    'Moroccan',
    'Egyptian',
    'Coffee & Tea',
    'Izakaya',
    'Tapas/Small Plates',
    'Tapas Bars',
    'Bartenders',
    'Internet Cafes',
    'Serbo Croatian',
    'Iberian',
    'Sicilian',
    'Acai Bowls',
    'Chinese',
    'Beer Gardens',
    'Scottish',
    'Middle Eastern',
    'Caribbean',
    'Bistros',
    'Pizza',
    'Arabic',
    'Hot Dogs',
    'Fish & Chips',
    'Drive-Thru Bars',
    'African',
    'Distilleries',
    'Asian Fusion',
    'Thai',
    'Wine Bars',
    'Ramen',
    'Brasseries',
    'Russian',
    'Irish Pub',
    'Vegan',
    'Tonkatsu',
    'Hot Pot',
    'Georgian',
    'Cafeteria',
    'Cajun/Creole',
    'Desserts',
    'Bed & Breakfast',
    'Bubble Tea',
    'Wine & Spirits',
    'Bangladeshi',
    'Cupcakes',
    'Cafes',
    'Dominican',
    'Austrian',
    'Cheesesteaks',
    'Gelato',
    'Mexican',
    'Food Stands',
    'Haitian',
    'Halal',
    'Portuguese',
    'Irish',
    'Salvadoran',
    'Seafood',
    'Trinidadian',
    'Dim Sum',
    'French',
    'Tuscan',
    'Teppanyaki',
    'British',
    'Kebab',
    'Korean',
    'Hainan',
    'Specialty Food',
    'Laotian',
    'Polish',
    'Czech',
    'Pop-Up Restaurants',
    'Singaporean',
    'Tiki Bars',
    'Soul Food',
    'Armenian',
    'Dinner Theater',
    'Hookah Bars',
    'Hong Kong Style Cafe',
    'Sardinian',
    'Local Flavor',
    'Waffles',
    'Pancakes',
    'Israeli',
    'Pretzels',
    'Cantonese',
    'Falafel',
    'Empanadas',
    'Chocolatiers & Shops',
    'Champagne Bars',
    'German',
    'Indonesian',
    'Barbeque',
    'Honduran',
    'Dumplings'
}

# %%
biz_df.isnull().sum()
# Out:
# business_id         0
# name                0
# address             0
# city                0
# state               0
# postal_code         0
# latitude            0
# longitude           0
# stars               0
# review_count        0
# is_open             0
# attributes      12348
# categories         95
# hours           16095
# dtype: int64

# %%
# Dropping any rows where the categories column is empty 

biz_df.dropna(subset=['categories'], inplace = True)

# %%
biz_df.isnull().sum()
# Out:
# business_id         0
# name                0
# address             0
# city                0
# state               0
# postal_code         0
# latitude            0
# longitude           0
# stars               0
# review_count        0
# is_open             0
# attributes      12254
# categories          0
# hours           16000
# dtype: int64

# %%
food_biz = biz_df[biz_df['categories'].str.contains('|'.join(food_categories))]
# Out:
# /var/folders/_g/fyn1m_tx7sbcpb8mtykvz6jw0000gn/T/ipykernel_15116/3492513972.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   food_biz = biz_df[biz_df['categories'].str.contains('|'.join(food_categories))]

# %%
food_biz.shape
# Out:
# (53052, 14)

# %%
food_biz.head()
# Out:
#                business_id                      name  \
# 3   MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4   mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 5   CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In
# 9   bBDDEgkFA1Otx9Lfe7BZUQ            Sonic Drive-In
# 10  UJsufbvfyfONHeWdvAHKjA                 Marshalls
#
#                       address           city state postal_code   latitude  \
# 3                 935 Race St   Philadelphia    PA       19107  39.955505
# 4               101 Walnut St     Green Lane    PA       18054  40.338183
# 5               615 S Main St   Ashland City    TN       37015  36.269593
# 9         2312 Dickerson Pike      Nashville    TN       37207  36.208102
# 10  21705 Village Lakes Sc Dr  Land O' Lakes    FL       34639  28.190459
#
#     longitude  stars  review_count  is_open  \
# 3  -75.155564    4.0            80        1
# 4  -75.471659    4.5            13        1
# 5  -87.058943    2.0             6        1
# 9  -86.768170    1.5            10        1
# 10 -82.457380    3.5             6        1
#
#                                            attributes  \
# 3   {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4   {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# 5   {'BusinessParking': 'None', 'BusinessAcceptsCr...
# 9   {'RestaurantsAttire': ''casual'', 'Restaurants...
# 10  {'RestaurantsPriceRange2': '2', 'BikeParking':...
#
#                                            categories  \
# 3   Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                           Brewpubs, Breweries, Food
# 5   Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 9   Ice Cream & Frozen Yogurt, Fast Food, Burgers,...
# 10               Department Stores, Shopping, Fashion
#
#                                                 hours
# 3   {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4   {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
# 5   {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 9   {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...
# 10  {'Monday': '9:30-21:30', 'Tuesday': '9:30-21:3...

# %% [markdown]
# ### Expanding the Attributes Column

# %%
# Extracting the various Attributes in the Dataset 

attr_df = food_biz['attributes'].apply(pd.Series)

# %%
attr_df.head()
# Out:
#    RestaurantsDelivery OutdoorSeating BusinessAcceptsCreditCards  \
# 3                False          False                      False
# 4                  NaN            NaN                       True
# 5                 True           True                       True
# 9                 True           True                       True
# 10                 NaN            NaN                       True
#
#                                       BusinessParking BikeParking  \
# 3   {'garage': False, 'street': True, 'validated':...        True
# 4   {'garage': None, 'street': None, 'validated': ...        True
# 5                                                None       False
# 9   {'garage': False, 'street': False, 'validated'...         NaN
# 10  {'garage': False, 'street': False, 'validated'...        True
#
#    RestaurantsPriceRange2 RestaurantsTakeOut ByAppointmentOnly     WiFi  \
# 3                       1               True             False  u'free'
# 4                     NaN               True               NaN      NaN
# 5                       1               True             False    u'no'
# 9                       1               True             False    u'no'
# 10                      2                NaN               NaN      NaN
#
#     Alcohol  ... BestNights BYOB Corkage BYOBCorkage AcceptsInsurance  \
# 3   u'none'  ...        NaN  NaN     NaN         NaN              NaN
# 4       NaN  ...        NaN  NaN     NaN         NaN              NaN
# 5   u'none'  ...        NaN  NaN     NaN         NaN              NaN
# 9   u'none'  ...        NaN  NaN     NaN         NaN              NaN
# 10      NaN  ...        NaN  NaN     NaN         NaN              NaN
#
#    RestaurantsCounterService Open24Hours AgesAllowed DietaryRestrictions  \
# 3                        NaN         NaN         NaN                 NaN
# 4                        NaN         NaN         NaN                 NaN
# 5                        NaN         NaN         NaN                 NaN
# 9                        NaN         NaN         NaN                 NaN
# 10                       NaN         NaN         NaN                 NaN
#
#    HairSpecializesIn
# 3                NaN
# 4                NaN
# 5                NaN
# 9                NaN
# 10               NaN
#
# [5 rows x 39 columns]

# %%
attr_df.columns
# Out:
# Index(['RestaurantsDelivery', 'OutdoorSeating', 'BusinessAcceptsCreditCards',
#        'BusinessParking', 'BikeParking', 'RestaurantsPriceRange2',
#        'RestaurantsTakeOut', 'ByAppointmentOnly', 'WiFi', 'Alcohol', 'Caters',
#        'WheelchairAccessible', 'GoodForKids', 'RestaurantsAttire',
#        'RestaurantsReservations', 'Ambience', 'CoatCheck', 'DogsAllowed',
#        'RestaurantsTableService', 'RestaurantsGoodForGroups', 'HasTV',
#        'HappyHour', 'DriveThru', 'GoodForMeal', 'NoiseLevel',
#        'BusinessAcceptsBitcoin', 'Smoking', 'Music', 'GoodForDancing',
#        'BestNights', 'BYOB', 'Corkage', 'BYOBCorkage', 'AcceptsInsurance',
#        'RestaurantsCounterService', 'Open24Hours', 'AgesAllowed',
#        'DietaryRestrictions', 'HairSpecializesIn'],
#       dtype='object')

# %%
attr_df.drop('HairSpecializesIn', inplace = True, axis = 1)

# %%
food_biz.drop('attributes', inplace = True, axis = 1)
food_biz = pd.concat([food_biz, attr_df], axis = 1)

# %%
food_biz.head()
# Out:
#                business_id                      name  \
# 3   MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4   mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 5   CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In
# 9   bBDDEgkFA1Otx9Lfe7BZUQ            Sonic Drive-In
# 10  UJsufbvfyfONHeWdvAHKjA                 Marshalls
#
#                       address           city state postal_code   latitude  \
# 3                 935 Race St   Philadelphia    PA       19107  39.955505
# 4               101 Walnut St     Green Lane    PA       18054  40.338183
# 5               615 S Main St   Ashland City    TN       37015  36.269593
# 9         2312 Dickerson Pike      Nashville    TN       37207  36.208102
# 10  21705 Village Lakes Sc Dr  Land O' Lakes    FL       34639  28.190459
#
#     longitude  stars  review_count  ...  GoodForDancing BestNights BYOB  \
# 3  -75.155564    4.0            80  ...             NaN        NaN  NaN
# 4  -75.471659    4.5            13  ...             NaN        NaN  NaN
# 5  -87.058943    2.0             6  ...             NaN        NaN  NaN
# 9  -86.768170    1.5            10  ...             NaN        NaN  NaN
# 10 -82.457380    3.5             6  ...             NaN        NaN  NaN
#
#    Corkage BYOBCorkage AcceptsInsurance RestaurantsCounterService Open24Hours  \
# 3      NaN         NaN              NaN                       NaN         NaN
# 4      NaN         NaN              NaN                       NaN         NaN
# 5      NaN         NaN              NaN                       NaN         NaN
# 9      NaN         NaN              NaN                       NaN         NaN
# 10     NaN         NaN              NaN                       NaN         NaN
#
#    AgesAllowed DietaryRestrictions
# 3          NaN                 NaN
# 4          NaN                 NaN
# 5          NaN                 NaN
# 9          NaN                 NaN
# 10         NaN                 NaN
#
# [5 rows x 51 columns]

# %%
# Number of businesses in each state
food_biz['state'].value_counts()
# Out:
# PA     11567
# FL      9142
# TN      4561
# IN      4219
# LA      4154
# MO      3958
# NJ      3420
# AZ      2851
# AB      2412
# NV      1971
# ID      1480
# CA      1329
# IL      1014
# DE       972
# HI         1
# XMS        1
# Name: state, dtype: int64

# %%
# Checking the number of reviews and the average rating according to the state

group_by_state = food_biz.groupby('state').agg({'stars':'mean', 'review_count':'sum'}).reset_index()
group_by_state.sort_values('review_count', ascending = False).reset_index()
# Out:
#     index state     stars  review_count
# 0      13    PA  3.540849        933691
# 1       4    FL  3.572522        731186
# 2       9    LA  3.657800        557668
# 3      14    TN  3.472484        408565
# 4      10    MO  3.480798        313708
# 5       8    IN  3.509836        301801
# 6       1    AZ  3.484216        241934
# 7      12    NV  3.576611        235567
# 8       2    CA  3.881114        209237
# 9      11    NJ  3.465351        156617
# 10      6    ID  3.632095         99490
# 11      0    AB  3.539179         62982
# 12      3    DE  3.436728         43720
# 13      7    IL  3.318540         33759
# 14      5    HI  3.500000            17
# 15     15   XMS  4.000000             5

# %%
# Checking the total reviews and the average rating according to the city in top 3 states

group_by_PA = food_biz[food_biz['state']=='PA'].groupby('city').agg({'stars':'mean', 'review_count':'sum'}).reset_index()
group_by_PA.sort_values('review_count', ascending = False).reset_index().head(30)
# Out:
#     index              city     stars  review_count
# 0     194      Philadelphia  3.569234        574595
# 1     275      West Chester  3.577068         14656
# 2     127   King of Prussia  3.428058         14628
# 3     157             Media  3.692913          9730
# 4      49      Conshohocken  3.538462          9065
# 5     273             Wayne  3.705000          8858
# 6     174          New Hope  3.699029          8612
# 7      56        Doylestown  3.684211          8519
# 8      10          Bensalem  3.255747          8322
# 9     176           Newtown  3.695238          7204
# 10      5           Ardmore  3.726316          7179
# 11    198      Phoenixville  3.525000          7175
# 12     72             Exton  3.328125          7131
# 13    137         Langhorne  3.288288          6933
# 14    153           Malvern  3.750000          6746
# 15    179       North Wales  3.468421          6570
# 16    281      Willow Grove  3.197802          6093
# 17    138          Lansdale  3.590909          5918
# 18    178        Norristown  3.531250          5574
# 19    126   King Of Prussia  3.163462          5547
# 20     95        Glen Mills  3.671233          5530
# 21     44      Collegeville  3.664384          5213
# 22    238       Springfield  3.264423          5187
# 23    124    Kennett Square  3.781609          5091
# 24    288           Yardley  3.639344          4859
# 25    116           Horsham  3.328358          4690
# 26      3            Ambler  3.708333          4508
# 27     55       Downingtown  3.506329          4462
# 28     27         Bryn Mawr  3.602740          4459
# 29    203  Plymouth Meeting  3.220000          4395

# %%
group_by_FL = food_biz[food_biz['state']=='FL'].groupby('city').agg({'stars':'mean', 'review_count':'sum'}).reset_index()
group_by_FL.sort_values('review_count', ascending = False).reset_index().head(30)
# Out:
#     index                city     stars  review_count
# 0     114               Tampa  3.566710        280833
# 1      16          Clearwater  3.569945         53257
# 2      86    Saint Petersburg  3.638132         47089
# 3     105      St. Petersburg  3.840967         32978
# 4      11             Brandon  3.448052         26881
# 5      17    Clearwater Beach  3.673684         18173
# 6      21             Dunedin  3.915000         17443
# 7     104      St. Pete Beach  3.724719         15344
# 8     101       St Petersburg  3.599174         15199
# 9      42               Largo  3.500000         14589
# 10     75           Riverview  3.299107         13995
# 11    136       Wesley Chapel  3.397790         12791
# 12     61         Palm Harbor  3.645078         12493
# 13     45                Lutz  3.564171         11384
# 14    120      Tarpon Springs  3.722222         10836
# 15     48       Madeira Beach  3.771084         10820
# 16     69       Pinellas Park  3.502874         10574
# 17     54     New Port Richey  3.422269          9511
# 18     98       St Pete Beach  3.852941          9095
# 19    132     Treasure Island  3.717742          7775
# 20     31  Indian Rocks Beach  3.828947          7693
# 21     58             Oldsmar  3.585526          6790
# 22     91            Seminole  3.564103          5676
# 23     84       Safety Harbor  4.122222          4920
# 24     70          Plant City  3.339844          4857
# 25     71         Port Richey  3.338384          4677
# 26     95         Spring Hill  3.371711          4579
# 27    135             Valrico  3.448276          3687
# 28     77              Ruskin  3.421875          3356
# 29    122      Temple Terrace  3.392857          3281

# %%
group_by_LA = food_biz[food_biz['state']=='LA'].groupby('city').agg({'stars':'mean', 'review_count':'sum'}).reset_index()
group_by_LA.sort_values('review_count', ascending = False).reset_index().head(30)
# Out:
#     index            city     stars  review_count
# 0      26     New Orleans  3.824870        479413
# 1      20        Metairie  3.382075         38361
# 2      16          Kenner  3.140927         13190
# 3      12          Gretna  3.509615          6741
# 4      14          Harvey  3.208333          4898
# 5      18         Marrero  3.191358          2866
# 6      13         Harahan  3.456140          2855
# 7       8       Chalmette  3.321429          1660
# 8      15       Jefferson  3.451613          1511
# 9      36        Westwego  3.568966          1385
# 10      4    Belle Chasse  3.444444          1145
# 11     33       Terrytown  3.586207           906
# 12     27     River Ridge  3.823529           552
# 13      1           Arabi  4.038462           418
# 14      6        Bucktown  4.500000           283
# 15      9         Elmwood  3.750000           239
# 16     30      Saint Rose  3.214286           223
# 17     22         Metarie  3.500000           199
# 18     34          Violet  3.700000           132
# 19     19          Meraux  2.916667           110
# 20      2        Avondale  2.416667            82
# 21     17          Luling  4.000000            79
# 22     23     NEW ORLEANS  4.500000            70
# 23     10  French Quarter  4.500000            69
# 24     24  NEW ORLEANS AP  1.500000            54
# 25     21       Metairie   4.000000            53
# 26      3     Belle Chase  3.250000            38
# 27     29   Saint Bernard  4.750000            32
# 28      0         Algiers  1.500000            28
# 29     28       Riveridge  2.500000            17

# %%
food_biz.to_csv('processed_datasets/restaurants.csv', index = False)
food_biz.to_json('processed_datasets/restaurants.json', orient='records', lines = True)

# %% [markdown]
# # Preprocessing Reviews Dataset

# %%
reviews_path = 'yelp_dataset/yelp_academic_dataset_review.json'
chunksize = 500000
chunks = []

for chunk in pd.read_json(reviews_path, lines = True, chunksize = chunksize):
    rel_data = chunk[['review_id', 'user_id', 'business_id', 'stars', 'text']]
    chunks.append(rel_data)

reviews_df = pd.concat(chunks, axis = 0, ignore_index = True)

# %%
reviews_df.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars                                               text
# 0      3  If you decide to eat here, just be aware it is...
# 1      5  I've taken a lot of spin classes over the year...
# 2      3  Family diner. Had the buffet. Eclectic assortm...
# 3      5  Wow!  Yummy, different,  delicious.   Our favo...
# 4      4  Cute interior and owner (?) gave us tour of up...

# %%
reviews_df.shape
# Out:
# (6990280, 5)

# %% [markdown]
# ### Filtering out Reviews which are not in our Restaurant list

# %%
food_reviews = pd.merge(reviews_df, food_biz[['business_id']], on = 'business_id', how = 'inner')
food_reviews.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  VJxlBnJmCDIy8DFG0kjSow  Iaee7y6zdSB3B-kRCo4z1w  XQfwVwDr-v0ZS3_CbbE5Xw
# 2  S6pQZQocMB1WHMjTRbt77A  ejFxLGqQcWNLdNByJlIhnQ  XQfwVwDr-v0ZS3_CbbE5Xw
# 3  WqgTKVqWVHDHjnjEsBvUgg  f7xa0p_1V9lx53iIGN5Sug  XQfwVwDr-v0ZS3_CbbE5Xw
# 4  M0wzFFb7pefOPcxeRVbLag  dCooFVCk8M1nVaQqcfTL3Q  XQfwVwDr-v0ZS3_CbbE5Xw
#
#    stars                                               text
# 0      3  If you decide to eat here, just be aware it is...
# 1      2  This is the second time we tried turning point...
# 2      4  The place is cute and the staff was very frien...
# 3      3  We came on a Saturday morning after waiting a ...
# 4      2  Mediocre at best. The decor is very nice, and ...

# %%
food_reviews.shape
# Out:
# (4480346, 5)

# %% [markdown]
# ### Preprocessing the Text Column

# %%
def preprocess_review_batch(review_batch):
    # Converting to lowercase
    review_batch = review_batch.str.lower()
    # Removing punctuations and specials characters
    review_batch = review_batch.str.replace(r'[^a-zA-Z\s]', '', regex = True)
    # Tokenizing the Text 
    tokens = review_batch.apply(word_tokenize)
    # Removing the stop words 
    tokens = tokens.apply(lambda x: [word for word in x if word not in set(stopwords.words('english'))])
    # Lemmatizing the tokens
    lemmatizer = WordNetLemmatizer()
    tokens = tokens.apply(lambda x: [lemmatizer.lemmatize(word) for word in x])
    processed_review = tokens.apply(lambda x: ' '.join(x))
    return processed_review

batch_size = 100000

processed_chunks = []

# Process the text column in batches
for i in range(0, len(food_reviews), batch_size):
    review_batch = food_reviews.iloc[i:i+batch_size]['text']
    processed_chunk = preprocess_review_batch(review_batch)
    processed_chunks.append(processed_chunk)

processed_text_series = pd.concat(processed_chunks, ignore_index=True)

# Add processed text back to reviews_df
food_reviews['processed_text'] = processed_text_series

# %%
food_reviews
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        VJxlBnJmCDIy8DFG0kjSow  Iaee7y6zdSB3B-kRCo4z1w
# 2        S6pQZQocMB1WHMjTRbt77A  ejFxLGqQcWNLdNByJlIhnQ
# 3        WqgTKVqWVHDHjnjEsBvUgg  f7xa0p_1V9lx53iIGN5Sug
# 4        M0wzFFb7pefOPcxeRVbLag  dCooFVCk8M1nVaQqcfTL3Q
# ...                         ...                     ...
# 4480341  qMMSJ2se0-G-V9K7y96EbQ  a4wr0eMRHjFqI66JoGpXog
# 4480342  WooR8MihE_bJ3qnYbDjizw  -MZSr4VErbuvzm8c5z2gbQ
# 4480343  QLVR6EcBV2lD2JpJrP9N_Q  k5RiHhMsd7zT6gO-sa8CiQ
# 4480344  cf3ft8457oGoiu9rW49cDQ  cS5J5Lw1xECApPjmk6dyJg
# 4480345  nGLcmo0D3IKrqqgK1kutlA  baGaUEUuXYQvTR9h4n9VKw
#
#                     business_id  stars  \
# 0        XQfwVwDr-v0ZS3_CbbE5Xw      3
# 1        XQfwVwDr-v0ZS3_CbbE5Xw      2
# 2        XQfwVwDr-v0ZS3_CbbE5Xw      4
# 3        XQfwVwDr-v0ZS3_CbbE5Xw      3
# 4        XQfwVwDr-v0ZS3_CbbE5Xw      2
# ...                         ...    ...
# 4480341  Tj9FmBCHd84kjAE9vcoBnw      1
# 4480342  Tj9FmBCHd84kjAE9vcoBnw      2
# 4480343  Tj9FmBCHd84kjAE9vcoBnw      1
# 4480344  Tj9FmBCHd84kjAE9vcoBnw      1
# 4480345  Tj9FmBCHd84kjAE9vcoBnw      1
#
#                                                       text  \
# 0        If you decide to eat here, just be aware it is...
# 1        This is the second time we tried turning point...
# 2        The place is cute and the staff was very frien...
# 3        We came on a Saturday morning after waiting a ...
# 4        Mediocre at best. The decor is very nice, and ...
# ...                                                    ...
# 4480341  I've always gone to this location for two reas...
# 4480342  This particular location is so painfully slow....
# 4480343  The owner is the biggest a-hole ever! He gave ...
# 4480344  Ask for Breasts and I'm always told there are ...
# 4480345  The chicken we ordered was cold wasn't even a ...
#
#                                             processed_text
# 0        decide eat aware going take hour beginning end...
# 1        second time tried turning point location first...
# 2        place cute staff friendly nice menu good brunc...
# 3        came saturday morning waiting month opening ho...
# 4        mediocre best decor nice like restaurant tryin...
# ...                                                    ...
# 4480341  ive always gone location two reason dont water...
# 4480342  particular location painfully slowalways chick...
# 4480343  owner biggest ahole ever gave much attitude in...
# 4480344  ask breast im always told none chicken chicken...
# 4480345  chicken ordered cold wasnt even full chicken p...
#
# [4480346 rows x 6 columns]

# %%
food_reviews.drop('text', axis = 1, inplace = True)

# %%
food_reviews.shape
# Out:
# (4480346, 5)

# %%
food_reviews.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  VJxlBnJmCDIy8DFG0kjSow  Iaee7y6zdSB3B-kRCo4z1w  XQfwVwDr-v0ZS3_CbbE5Xw
# 2  S6pQZQocMB1WHMjTRbt77A  ejFxLGqQcWNLdNByJlIhnQ  XQfwVwDr-v0ZS3_CbbE5Xw
# 3  WqgTKVqWVHDHjnjEsBvUgg  f7xa0p_1V9lx53iIGN5Sug  XQfwVwDr-v0ZS3_CbbE5Xw
# 4  M0wzFFb7pefOPcxeRVbLag  dCooFVCk8M1nVaQqcfTL3Q  XQfwVwDr-v0ZS3_CbbE5Xw
#
#    stars                                     processed_text
# 0      3  decide eat aware going take hour beginning end...
# 1      2  second time tried turning point location first...
# 2      4  place cute staff friendly nice menu good brunc...
# 3      3  came saturday morning waiting month opening ho...
# 4      2  mediocre best decor nice like restaurant tryin...

# %%
food_reviews.to_csv('processed_datasets/restaurant_reviews.csv', index = False)

# %%
food_biz.shape
# Out:
# (53052, 51)

# %%
food_reviews.shape
# Out:
# (4480346, 5)

# %% [markdown]
# # Preprocessing Users Dataset

# %%
users_path = 'yelp_dataset/yelp_academic_dataset_user.json'
chunksize = 500000
chunks = []

with tqdm() as pbar:
    for chunk in pd.read_json(users_path, lines = True, chunksize = chunksize):
        rel_data = chunk[['user_id', 'name', 'review_count', 'friends', 'fans', 'average_stars']]
        chunks.append(rel_data)
    
        pbar.update(1)

users_df = pd.concat(chunks, axis = 0, ignore_index = True)
# Out:
# python(46732) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# 4it [03:06, 46.75s/it]

# %%
users_df.head()
# Out:
#                   user_id    name  review_count  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79
#
#                                              friends  fans  average_stars
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267           3.91
# 1  ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138           3.74
# 2  LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...    52           3.32
# 3  enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...    28           4.27
# 4  PBK4q9KEEBHhFvSXCUirIw, 3FWPpM7KU1gXeOM_ZbYMbA...     1           3.54

# %%
users_df.shape
# Out:
# (1987897, 6)

# %% [markdown]
# ### Filtering out users who have reviews for Restaurants only

# %%
merged_df = pd.merge(users_df, food_reviews[['user_id']], on='user_id', how='inner')
restaurant_users = merged_df.drop_duplicates(subset='user_id', keep='first')
restaurant_users.reset_index(drop=True, inplace=True)

restaurant_users.head()
# Out:
#                   user_id    name  review_count  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79
#
#                                              friends  fans  average_stars
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267           3.91
# 1  ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138           3.74
# 2  LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...    52           3.32
# 3  enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...    28           4.27
# 4  PBK4q9KEEBHhFvSXCUirIw, 3FWPpM7KU1gXeOM_ZbYMbA...     1           3.54

# %%
restaurant_users.shape
# Out:
# (1450144, 6)

# %%
restaurant_users.to_csv('processed_datasets/restaurant_users.csv', index = False)

# %% [markdown]
# # Philadelphia

# %%
biz_philli = food_biz[food_biz['city'] == 'Philadelphia']
biz_philli.head()
# Out:
#                business_id                name             address  \
# 3   MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries         935 Race St
# 15  MUTTqe8uqyMdBl186RmNeA            Tuna Bar         205 Race St
# 19  ROeacJQwBeh05Rqg7F6TCg                 BAP       1224 South St
# 35  aPNXGTDkf-4bjhyMBQxqpQ          Craft Hall  901 N Delaware Ave
# 82  ppFCk9aQkM338Rgwpl2F5A                Wawa    3604 Chestnut St
#
#             city state postal_code   latitude  longitude  stars  review_count  \
# 3   Philadelphia    PA       19107  39.955505 -75.155564    4.0            80
# 15  Philadelphia    PA       19106  39.953949 -75.143226    4.0           245
# 19  Philadelphia    PA       19147  39.943223 -75.162568    4.5           205
# 35  Philadelphia    PA       19123  39.962582 -75.135657    3.5            65
# 82  Philadelphia    PA       19104  39.954573 -75.194894    3.0            56
#
#     ...  GoodForDancing BestNights BYOB Corkage BYOBCorkage AcceptsInsurance  \
# 3   ...             NaN        NaN  NaN     NaN         NaN              NaN
# 15  ...             NaN        NaN  NaN     NaN         NaN              NaN
# 19  ...             NaN        NaN  NaN     NaN         NaN              NaN
# 35  ...             NaN        NaN  NaN     NaN         NaN              NaN
# 82  ...             NaN        NaN  NaN     NaN         NaN              NaN
#
#    RestaurantsCounterService Open24Hours AgesAllowed DietaryRestrictions
# 3                        NaN         NaN         NaN                 NaN
# 15                       NaN         NaN         NaN                 NaN
# 19                       NaN         NaN         NaN                 NaN
# 35                       NaN         NaN         NaN                 NaN
# 82                       NaN         NaN         NaN                 NaN
#
# [5 rows x 51 columns]

# %%
biz_philli.shape
# Out:
# (5078, 51)

# %%
reviews_philli = pd.merge(food_reviews, biz_philli[['business_id']], on = 'business_id', how = 'inner')
reviews_philli.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 1  HME_ksGph3se7Aze5hxa-Q  kSMOJwJXuEUqzfmuFncK4A  kxX2SOes4o-D3ZQBkiMRfA
# 2  EJWyA5wpdVMji1j4TwSZqQ  mqBWACmaHflW4eh_Ofp16Q  kxX2SOes4o-D3ZQBkiMRfA
# 3  T_kAb2NeylB-JdNDKphryw  Z-xgVb4nM42943m2wbBkFw  kxX2SOes4o-D3ZQBkiMRfA
# 4  NENaCqb6TNj5CyY1LOdI6Q  2SEoXb6r6hPKrl9V9VzBgA  kxX2SOes4o-D3ZQBkiMRfA
#
#    stars                                     processed_text
# 0      5  wow yummy different delicious favorite lamb cu...
# 1      2  dinein get star disappointing service venue fa...
# 2      5  long hiatus reviewing awaken mouth yelp hibern...
# 3      5  weve eaten time seems time get even better shr...
# 4      5  came philly family event stayed little dinner ...

# %%
reviews_philli.shape
# Out:
# (592565, 5)

# %%
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
def get_sentiment_scores(text):
    sentiment = sia.polarity_scores(text)
    return sentiment['compound']
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/kirthanpakki/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
reviews_philli['sentiment_scores'] = reviews_philli['processed_text'].apply(get_sentiment_scores)

# %%
reviews_philli.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 1  HME_ksGph3se7Aze5hxa-Q  kSMOJwJXuEUqzfmuFncK4A  kxX2SOes4o-D3ZQBkiMRfA
# 2  EJWyA5wpdVMji1j4TwSZqQ  mqBWACmaHflW4eh_Ofp16Q  kxX2SOes4o-D3ZQBkiMRfA
# 3  T_kAb2NeylB-JdNDKphryw  Z-xgVb4nM42943m2wbBkFw  kxX2SOes4o-D3ZQBkiMRfA
# 4  NENaCqb6TNj5CyY1LOdI6Q  2SEoXb6r6hPKrl9V9VzBgA  kxX2SOes4o-D3ZQBkiMRfA
#
#    stars                                     processed_text  sentiment_scores
# 0      5  wow yummy different delicious favorite lamb cu...            0.9652
# 1      2  dinein get star disappointing service venue fa...            0.0516
# 2      5  long hiatus reviewing awaken mouth yelp hibern...            0.9932
# 3      5  weve eaten time seems time get even better shr...            0.9263
# 4      5  came philly family event stayed little dinner ...            0.7533

# %%
reviews_philli['final_rating'] = reviews_philli['stars'] + reviews_philli['sentiment_scores']

# %%
reviews_philli.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 1  HME_ksGph3se7Aze5hxa-Q  kSMOJwJXuEUqzfmuFncK4A  kxX2SOes4o-D3ZQBkiMRfA
# 2  EJWyA5wpdVMji1j4TwSZqQ  mqBWACmaHflW4eh_Ofp16Q  kxX2SOes4o-D3ZQBkiMRfA
# 3  T_kAb2NeylB-JdNDKphryw  Z-xgVb4nM42943m2wbBkFw  kxX2SOes4o-D3ZQBkiMRfA
# 4  NENaCqb6TNj5CyY1LOdI6Q  2SEoXb6r6hPKrl9V9VzBgA  kxX2SOes4o-D3ZQBkiMRfA
#
#    stars                                     processed_text  sentiment_scores  \
# 0      5  wow yummy different delicious favorite lamb cu...            0.9652
# 1      2  dinein get star disappointing service venue fa...            0.0516
# 2      5  long hiatus reviewing awaken mouth yelp hibern...            0.9932
# 3      5  weve eaten time seems time get even better shr...            0.9263
# 4      5  came philly family event stayed little dinner ...            0.7533
#
#    final_rating
# 0        5.9652
# 1        2.0516
# 2        5.9932
# 3        5.9263
# 4        5.7533

# %%
reviews_philli.to_csv('processed_datasets/philadelphia/reviews_philli.csv', index = False)
biz_philli.to_csv('processed_datasets/philadelphia/restuarants_philli.csv', index = False)

# %%
users_philli = pd.merge(restaurant_users, reviews_philli[['user_id']], on='user_id', how='inner')
users_philli = users_philli.drop_duplicates(subset='user_id', keep='first')
users_philli.reset_index(drop=True, inplace=True)

# %%
users_philli.shape
# Out:
# (199676, 6)

# %%
users_philli.to_csv('processed_datasets/philadelphia/users_philli.csv', index = False)

# %% [markdown]
# ### Creating the Item-User Matrix

# %%
reviews_philli.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 1  HME_ksGph3se7Aze5hxa-Q  kSMOJwJXuEUqzfmuFncK4A  kxX2SOes4o-D3ZQBkiMRfA
# 2  EJWyA5wpdVMji1j4TwSZqQ  mqBWACmaHflW4eh_Ofp16Q  kxX2SOes4o-D3ZQBkiMRfA
# 3  T_kAb2NeylB-JdNDKphryw  Z-xgVb4nM42943m2wbBkFw  kxX2SOes4o-D3ZQBkiMRfA
# 4  NENaCqb6TNj5CyY1LOdI6Q  2SEoXb6r6hPKrl9V9VzBgA  kxX2SOes4o-D3ZQBkiMRfA
#
#    stars                                     processed_text  sentiment_scores  \
# 0      5  wow yummy different delicious favorite lamb cu...            0.9652
# 1      2  dinein get star disappointing service venue fa...            0.0516
# 2      5  long hiatus reviewing awaken mouth yelp hibern...            0.9932
# 3      5  weve eaten time seems time get even better shr...            0.9263
# 4      5  came philly family event stayed little dinner ...            0.7533
#
#    final_rating
# 0        5.9652
# 1        2.0516
# 2        5.9932
# 3        5.9263
# 4        5.7533

# %%
reviews_philli.drop(columns = ['stars', 'processed_text','sentiment_scores'], axis = 1, inplace=True)

# %%
reviews_philli.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 1  HME_ksGph3se7Aze5hxa-Q  kSMOJwJXuEUqzfmuFncK4A  kxX2SOes4o-D3ZQBkiMRfA
# 2  EJWyA5wpdVMji1j4TwSZqQ  mqBWACmaHflW4eh_Ofp16Q  kxX2SOes4o-D3ZQBkiMRfA
# 3  T_kAb2NeylB-JdNDKphryw  Z-xgVb4nM42943m2wbBkFw  kxX2SOes4o-D3ZQBkiMRfA
# 4  NENaCqb6TNj5CyY1LOdI6Q  2SEoXb6r6hPKrl9V9VzBgA  kxX2SOes4o-D3ZQBkiMRfA
#
#    final_rating
# 0        5.9652
# 1        2.0516
# 2        5.9932
# 3        5.9263
# 4        5.7533

# %%
biz_philli.head()
# Out:
#                business_id                name             address  \
# 3   MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries         935 Race St
# 15  MUTTqe8uqyMdBl186RmNeA            Tuna Bar         205 Race St
# 19  ROeacJQwBeh05Rqg7F6TCg                 BAP       1224 South St
# 35  aPNXGTDkf-4bjhyMBQxqpQ          Craft Hall  901 N Delaware Ave
# 82  ppFCk9aQkM338Rgwpl2F5A                Wawa    3604 Chestnut St
#
#             city state postal_code   latitude  longitude  stars  review_count  \
# 3   Philadelphia    PA       19107  39.955505 -75.155564    4.0            80
# 15  Philadelphia    PA       19106  39.953949 -75.143226    4.0           245
# 19  Philadelphia    PA       19147  39.943223 -75.162568    4.5           205
# 35  Philadelphia    PA       19123  39.962582 -75.135657    3.5            65
# 82  Philadelphia    PA       19104  39.954573 -75.194894    3.0            56
#
#     ...  GoodForDancing BestNights BYOB Corkage BYOBCorkage AcceptsInsurance  \
# 3   ...             NaN        NaN  NaN     NaN         NaN              NaN
# 15  ...             NaN        NaN  NaN     NaN         NaN              NaN
# 19  ...             NaN        NaN  NaN     NaN         NaN              NaN
# 35  ...             NaN        NaN  NaN     NaN         NaN              NaN
# 82  ...             NaN        NaN  NaN     NaN         NaN              NaN
#
#    RestaurantsCounterService Open24Hours AgesAllowed DietaryRestrictions
# 3                        NaN         NaN         NaN                 NaN
# 15                       NaN         NaN         NaN                 NaN
# 19                       NaN         NaN         NaN                 NaN
# 35                       NaN         NaN         NaN                 NaN
# 82                       NaN         NaN         NaN                 NaN
#
# [5 rows x 51 columns]

# %%
res_philli = biz_philli[['business_id', 'name', 'stars']]

# %%
res_philli.head()
# Out:
#                business_id                name  stars
# 3   MTSW4McQd7CbVtyjqoe9mw  St Honore Pastries    4.0
# 15  MUTTqe8uqyMdBl186RmNeA            Tuna Bar    4.0
# 19  ROeacJQwBeh05Rqg7F6TCg                 BAP    4.5
# 35  aPNXGTDkf-4bjhyMBQxqpQ          Craft Hall    3.5
# 82  ppFCk9aQkM338Rgwpl2F5A                Wawa    3.0

# %%
users_philli.head()
# Out:
#                   user_id    name  review_count  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333
# 2  q_QQ5kBBwlCcbL1s4NVK3g    Jane          1221
# 3  AUi8MPWJ0mLkMfwbui27lg    John           109
# 4  1McG5Rn_UDkmlkZOrsdptg  Teresa             7
#
#                                              friends  fans  average_stars
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267           3.91
# 1  ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138           3.74
# 2  xBDpTUbai0DXrvxCe3X16Q, 7GPNBO496aecrjJfW6UWtg...  1357           3.85
# 3  gy5fWeSv3Gamuq9Ox4MV4g, lMr3LWU6kPFLTmCpDkACxg...     4           3.40
# 4  piejMEdRkGB7-1aL4lL5NQ, X0zFOU6iG95-feQKOXkgrA...     1           4.29

# %%
users_philli.drop(columns = ['review_count', 'friends', 'fans'], axis = 1, inplace = True)

# %%
users_philli.head()
# Out:
#                   user_id    name  average_stars
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           3.91
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel           3.74
# 2  q_QQ5kBBwlCcbL1s4NVK3g    Jane           3.85
# 3  AUi8MPWJ0mLkMfwbui27lg    John           3.40
# 4  1McG5Rn_UDkmlkZOrsdptg  Teresa           4.29

# %%
# Merge reviews_philli with users_philli to get user information
merged_df = pd.merge(reviews_philli, users_philli, on='user_id', how='left')

# Merge merged_df with res_philli to get restaurant information
merged_df = pd.merge(merged_df, res_philli, on='business_id', how='left')

# Select relevant columns for the User-Item Ratings matrix
ratings_df = merged_df[['user_id', 'business_id', 'final_rating']]

# Aggregate duplicate entries by taking the mean of the ratings for each combination of user_id and business_id.
ratings_df = ratings_df.groupby(['user_id', 'business_id']).mean().reset_index()

# Pivot the DataFrame to create the User-Item Ratings matrix
ratings_matrix = ratings_df.pivot(index='user_id', columns='business_id', values='final_rating')

# Display the resulting ratings matrix
print(ratings_matrix)
# Out:
# business_id             --OS_I7dnABrXvRCCuWOGQ  --sXnWH9Xm6_NvIjyuA99w  \
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
# ...                                        ...                     ...
# zzvCl_egPyWpxO7EvWc2IA                     NaN                     NaN
# zzvLsOhm7gBMQDygMBDrHg                     NaN                     NaN
# zzwYLnmIvj8C7wJmRjtkRA                     NaN                     NaN
# zzx7J3zheFF3zf5YYfDAMg                     NaN                     NaN
# zzzMBVS73g3ZJ7qL8JyhiA                     NaN                     NaN
#
# business_id             -0TffRSXXIlBYVbb5AwfTg  -1B9pP_CrRBJYPICE5WbRA  \
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
# ...                                        ...                     ...
# zzvCl_egPyWpxO7EvWc2IA                     NaN                     NaN
# zzvLsOhm7gBMQDygMBDrHg                     NaN                     NaN
# zzwYLnmIvj8C7wJmRjtkRA                     NaN                     NaN
# zzx7J3zheFF3zf5YYfDAMg                     NaN                     NaN
# zzzMBVS73g3ZJ7qL8JyhiA                     NaN                     NaN
#
# business_id             -1DxQ1CxSc_JCxzKm9bglg  -3ArWZfDjfab8qVHf3WVtg  \
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
# ...                                        ...                     ...
# zzvCl_egPyWpxO7EvWc2IA                     NaN                     NaN
# zzvLsOhm7gBMQDygMBDrHg                     NaN                     NaN
# zzwYLnmIvj8C7wJmRjtkRA                     NaN                     NaN
# zzx7J3zheFF3zf5YYfDAMg                     NaN                     NaN
# zzzMBVS73g3ZJ7qL8JyhiA                     NaN                     NaN
#
# business_id             -3e3CP3FFc-rvJj_-_airw  -3m_nXlyvdKAVNNmVirpGQ  \
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                  3.1481                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
# ...                                        ...                     ...
# zzvCl_egPyWpxO7EvWc2IA                     NaN                     NaN
# zzvLsOhm7gBMQDygMBDrHg                     NaN                     NaN
# zzwYLnmIvj8C7wJmRjtkRA                     NaN                     NaN
# zzx7J3zheFF3zf5YYfDAMg                     NaN                     NaN
# zzzMBVS73g3ZJ7qL8JyhiA                     NaN                     NaN
#
# business_id             -5Rah4ZvWsDu4oilUZxhtw  -63ytt5vkWof-M9NDGTkng  ...  \
# user_id                                                                 ...
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN  ...
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN  ...
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN  ...
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN  ...
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN  ...
# ...                                        ...                     ...  ...
# zzvCl_egPyWpxO7EvWc2IA                     NaN                     NaN  ...
# zzvLsOhm7gBMQDygMBDrHg                     NaN                     NaN  ...
# zzwYLnmIvj8C7wJmRjtkRA                     NaN                     NaN  ...
# zzx7J3zheFF3zf5YYfDAMg                     NaN                     NaN  ...
# zzzMBVS73g3ZJ7qL8JyhiA                     NaN                     NaN  ...
#
# business_id             zuKnCtZQKZqnvEaKVnwVVQ  zucC7rHpXPYBu7aEqj0NUw  \
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
# ...                                        ...                     ...
# zzvCl_egPyWpxO7EvWc2IA                     NaN                     NaN
# zzvLsOhm7gBMQDygMBDrHg                     NaN                     NaN
# zzwYLnmIvj8C7wJmRjtkRA                     NaN                     NaN
# zzx7J3zheFF3zf5YYfDAMg                     NaN                     NaN
# zzzMBVS73g3ZJ7qL8JyhiA                     NaN                     NaN
#
# business_id             zujdPV3HT-Y-CKE1GgkMHQ  zvvl3c1FO3O3BZdhusficA  \
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
# ...                                        ...                     ...
# zzvCl_egPyWpxO7EvWc2IA                     NaN                     NaN
# zzvLsOhm7gBMQDygMBDrHg                     NaN                     NaN
# zzwYLnmIvj8C7wJmRjtkRA                     NaN                     NaN
# zzx7J3zheFF3zf5YYfDAMg                     NaN                     NaN
# zzzMBVS73g3ZJ7qL8JyhiA                     NaN                     NaN
#
# business_id             zwTmOj4B_OVPMTMYijQiKg  zwd4dyQ5ovnjVojWfAuhMw  \
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
# ...                                        ...                     ...
# zzvCl_egPyWpxO7EvWc2IA                     NaN                     NaN
# zzvLsOhm7gBMQDygMBDrHg                     NaN                     NaN
# zzwYLnmIvj8C7wJmRjtkRA                     NaN                     NaN
# zzx7J3zheFF3zf5YYfDAMg                     NaN                     NaN
# zzzMBVS73g3ZJ7qL8JyhiA                     NaN                     NaN
#
# business_id             zxRmQ_FWVowh8rlzLCSURQ  zxY4DgtXsVHihSUpsmwamg  \
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
# ...                                        ...                     ...
# zzvCl_egPyWpxO7EvWc2IA                     NaN                     NaN
# zzvLsOhm7gBMQDygMBDrHg                     NaN                     NaN
# zzwYLnmIvj8C7wJmRjtkRA                     NaN                     NaN
# zzx7J3zheFF3zf5YYfDAMg                     NaN                     NaN
# zzzMBVS73g3ZJ7qL8JyhiA                     NaN                     NaN
#
# business_id             zy2p8yfx_fgXMCCUo8nWsA  zz3E7kmJI2r2JseE6LAnrw
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
# ...                                        ...                     ...
# zzvCl_egPyWpxO7EvWc2IA                     NaN                     NaN
# zzvLsOhm7gBMQDygMBDrHg                     NaN                     NaN
# zzwYLnmIvj8C7wJmRjtkRA                     NaN                     NaN
# zzx7J3zheFF3zf5YYfDAMg                     NaN                     NaN
# zzzMBVS73g3ZJ7qL8JyhiA                     NaN                     NaN
#
# [199676 rows x 5078 columns]

# %%
ratings_matrix.head()
# Out:
# business_id             --OS_I7dnABrXvRCCuWOGQ  --sXnWH9Xm6_NvIjyuA99w  \
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
#
# business_id             -0TffRSXXIlBYVbb5AwfTg  -1B9pP_CrRBJYPICE5WbRA  \
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
#
# business_id             -1DxQ1CxSc_JCxzKm9bglg  -3ArWZfDjfab8qVHf3WVtg  \
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
#
# business_id             -3e3CP3FFc-rvJj_-_airw  -3m_nXlyvdKAVNNmVirpGQ  \
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                  3.1481                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
#
# business_id             -5Rah4ZvWsDu4oilUZxhtw  -63ytt5vkWof-M9NDGTkng  ...  \
# user_id                                                                 ...
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN  ...
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN  ...
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN  ...
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN  ...
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN  ...
#
# business_id             zuKnCtZQKZqnvEaKVnwVVQ  zucC7rHpXPYBu7aEqj0NUw  \
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
#
# business_id             zujdPV3HT-Y-CKE1GgkMHQ  zvvl3c1FO3O3BZdhusficA  \
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
#
# business_id             zwTmOj4B_OVPMTMYijQiKg  zwd4dyQ5ovnjVojWfAuhMw  \
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
#
# business_id             zxRmQ_FWVowh8rlzLCSURQ  zxY4DgtXsVHihSUpsmwamg  \
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
#
# business_id             zy2p8yfx_fgXMCCUo8nWsA  zz3E7kmJI2r2JseE6LAnrw
# user_id
# --2tyArRmSoyKx5r-FVG0A                     NaN                     NaN
# --2vR0DIsmQ6WfcSzKWigw                     NaN                     NaN
# --4AjktZiHowEIBCMd4CZA                     NaN                     NaN
# --4_p6Z3tKadJcr9Non_Vw                     NaN                     NaN
# --6GckBYtTa4hj8pT09oAg                     NaN                     NaN
#
# [5 rows x 5078 columns]

# %%
user_item_ratings = ratings_matrix.values

# %%
ratings_matrix.to_csv('processed_datasets/philadelphia/ratings_matrix_philli.csv')

# %% [markdown]
# # Tampa

# %%
food_biz = pd.read_csv('processed_datasets/restaurants.csv')
# Out:
# /var/folders/_g/fyn1m_tx7sbcpb8mtykvz6jw0000gn/T/ipykernel_53309/1591363343.py:1: DtypeWarning: Columns (18,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   food_biz = pd.read_csv('processed_datasets/restaurants.csv')

# %%
reviews_path = 'processed_datasets/restaurant_reviews.csv'
chunksize = 500000
chunks = []

for chunk in pd.read_csv(reviews_path, chunksize = chunksize):
    chunks.append(chunk)

food_reviews = pd.concat(chunks, axis = 0, ignore_index = True)

# %%
food_reviews.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  VJxlBnJmCDIy8DFG0kjSow  Iaee7y6zdSB3B-kRCo4z1w  XQfwVwDr-v0ZS3_CbbE5Xw
# 2  S6pQZQocMB1WHMjTRbt77A  ejFxLGqQcWNLdNByJlIhnQ  XQfwVwDr-v0ZS3_CbbE5Xw
# 3  WqgTKVqWVHDHjnjEsBvUgg  f7xa0p_1V9lx53iIGN5Sug  XQfwVwDr-v0ZS3_CbbE5Xw
# 4  M0wzFFb7pefOPcxeRVbLag  dCooFVCk8M1nVaQqcfTL3Q  XQfwVwDr-v0ZS3_CbbE5Xw
#
#    stars                                     processed_text
# 0      3  decide eat aware going take hour beginning end...
# 1      2  second time tried turning point location first...
# 2      4  place cute staff friendly nice menu good brunc...
# 3      3  came saturday morning waiting month opening ho...
# 4      2  mediocre best decor nice like restaurant tryin...

# %%
food_reviews.shape
# Out:
# (4480346, 5)

# %%
users_path = 'processed_datasets/restaurant_users.csv'
chunksize = 500000
chunks = []

for chunk in pd.read_csv(users_path, chunksize = chunksize):
    chunks.append(chunk)

res_users = pd.concat(chunks, axis = 0, ignore_index = True)

# %%
res_users.head()
# Out:
#                   user_id    name  review_count  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79
#
#                                              friends  fans  average_stars
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267           3.91
# 1  ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138           3.74
# 2  LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...    52           3.32
# 3  enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...    28           4.27
# 4  PBK4q9KEEBHhFvSXCUirIw, 3FWPpM7KU1gXeOM_ZbYMbA...     1           3.54

# %%
res_users.shape
# Out:
# (1450144, 6)

# %%
biz_tampa = food_biz[food_biz['city'] == 'Tampa']
biz_tampa.head()
# Out:
#                business_id                name                 address   city  \
# 21  0qNpTGTcqPwOLi2hADx4Xw    Charlie's Market        2815 E Sligh Ave  Tampa
# 38  RK6-cJ9hj53RzOlCBmpT-g             Impasto                     NaN  Tampa
# 59  zFvqulgAYOpSG2t1v8AZ-w       The Cake Drip         1625 W Snow Cir  Tampa
# 74  QjV4v7q_pt7tt3K1US7IHg  PDQ Temple Terrace       5112 E Fowler Ave  Tampa
# 93  Ucl9Vo5lwrUmYbV8Dv8X5g  O'Briens Irish Pub  15435 N Dale Mabry Hwy  Tampa
#
#    state postal_code   latitude  longitude  stars  review_count  ...  \
# 21    FL       33610  28.010360 -82.430042    3.0             9  ...
# 38    FL       33611  27.890814 -82.502346    5.0             5  ...
# 59    FL       33606  27.935753 -82.476470    4.0            40  ...
# 74    FL       33617  28.054888 -82.399548    3.0             5  ...
# 93    FL       33618  28.092360 -82.500588    4.0           108  ...
#
#     GoodForDancing                                         BestNights BYOB  \
# 21             NaN                                                NaN  NaN
# 38             NaN                                                NaN  NaN
# 59             NaN                                                NaN  NaN
# 74             NaN                                                NaN  NaN
# 93            True  {'monday': False, 'tuesday': False, 'friday': ...  NaN
#
#    Corkage BYOBCorkage AcceptsInsurance RestaurantsCounterService Open24Hours  \
# 21     NaN         NaN              NaN                       NaN         NaN
# 38     NaN         NaN              NaN                       NaN         NaN
# 59     NaN         NaN              NaN                       NaN         NaN
# 74     NaN         NaN              NaN                       NaN         NaN
# 93     NaN         NaN              NaN                       NaN         NaN
#
#    AgesAllowed DietaryRestrictions
# 21         NaN                 NaN
# 38         NaN                 NaN
# 59         NaN                 NaN
# 74         NaN                 NaN
# 93         NaN                 NaN
#
# [5 rows x 51 columns]

# %%
biz_tampa.shape
# Out:
# (3043, 51)

# %%
reviews_tampa = pd.merge(food_reviews, biz_tampa[['business_id']], on = 'business_id', how = 'inner')
reviews_tampa.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  OAhBYw8IQ6wlfw1owXWRWw  1C2lxzUo1Hyye4RFIXly3g  BVndHaLihEYbr76Z0CMEGw
# 1  R3TNDNoRUiVfRgvvczy0mg  -Dt5o6GpQcXQfVeWpHNtDg  BVndHaLihEYbr76Z0CMEGw
# 2  OZpHUjMx5vyK0Hn2Uim_AQ  kiTsCsc_vtGXnzVz738w2g  BVndHaLihEYbr76Z0CMEGw
# 3  dmjtUSlyc-3EA1Tv26AWJw  NKFBcrL56W7eHxPXxyPTxA  BVndHaLihEYbr76Z0CMEGw
# 4  kcV2upXjWLWuJPAt9QICbw  ZuF1R91KH924zJwPTmFi4g  BVndHaLihEYbr76Z0CMEGw
#
#    stars                                     processed_text
# 0      5  great place breakfast waffle fluffy perfect ho...
# 1      5  came based recommendation received street does...
# 2      5  found place searching yelp definitely good pla...
# 3      2  supper pm disappointed ordered waitress nice c...
# 4      4  good little mom pop breakfast place food reall...

# %%
reviews_tampa.shape
# Out:
# (290145, 5)

# %%
reviews_tampa['processed_text'] = reviews_tampa['processed_text'].astype(str)
reviews_tampa['sentiment_scores'] = reviews_tampa['processed_text'].apply(get_sentiment_scores)
reviews_tampa['final_rating'] = reviews_tampa['stars'] + reviews_tampa['sentiment_scores']

# %%
reviews_tampa.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  OAhBYw8IQ6wlfw1owXWRWw  1C2lxzUo1Hyye4RFIXly3g  BVndHaLihEYbr76Z0CMEGw
# 1  R3TNDNoRUiVfRgvvczy0mg  -Dt5o6GpQcXQfVeWpHNtDg  BVndHaLihEYbr76Z0CMEGw
# 2  OZpHUjMx5vyK0Hn2Uim_AQ  kiTsCsc_vtGXnzVz738w2g  BVndHaLihEYbr76Z0CMEGw
# 3  dmjtUSlyc-3EA1Tv26AWJw  NKFBcrL56W7eHxPXxyPTxA  BVndHaLihEYbr76Z0CMEGw
# 4  kcV2upXjWLWuJPAt9QICbw  ZuF1R91KH924zJwPTmFi4g  BVndHaLihEYbr76Z0CMEGw
#
#    stars                                     processed_text  sentiment_scores  \
# 0      5  great place breakfast waffle fluffy perfect ho...            0.9477
# 1      5  came based recommendation received street does...            0.9310
# 2      5  found place searching yelp definitely good pla...            0.9823
# 3      2  supper pm disappointed ordered waitress nice c...            0.9175
# 4      4  good little mom pop breakfast place food reall...            0.9432
#
#    final_rating
# 0        5.9477
# 1        5.9310
# 2        5.9823
# 3        2.9175
# 4        4.9432

# %%
users_tampa = pd.merge(res_users, reviews_tampa[['user_id']], on='user_id', how='inner')
users_tampa = users_tampa.drop_duplicates(subset='user_id', keep='first')
users_tampa.reset_index(drop=True, inplace=True)

# %%
users_tampa.head()
# Out:
#                   user_id         name  review_count  \
# 0  FT9CFS39sjZxVjCTrDHmdg    Stephanie           201
# 1  OlJ9vcVFB1iEKcZO-MS3cQ  Joz Joz Joz           348
# 2  NIhcRW6DWvk1JQhDhXwgOQ          Lia          2288
# 3  rppTTi-kfF8-qyiArNemag        Helen           460
# 4  QJI9OSEn6ujRCtrX06vs1w            J          1982
#
#                                              friends  fans  average_stars
# 0  ElaFwOTdEpkiYPkHMpOwXQ, nbnftigv3fj8oS6k-waLYQ...     5           3.52
# 1  iBeN7TtSJrq-dLwj-EevFw, oSN3M4_WKdlTsnpgqPDiBg...   116           3.93
# 2  T1upaPMzuW7pNj74fO1rjA, CP28puvAEimt4ziuGTDaHA...   345           3.69
# 3  HzoQKKHDq9BI37dyJAAtGA, Inh7WS8hpmiUmNDhtLK-ZQ...    49           3.33
# 4  RyPeT_ICAtX8ah9dhDpEFw, W8r4aKPZFT3GPIQQDbqB6Q...   316           3.61

# %%
users_tampa.shape
# Out:
# (115755, 6)

# %%
reviews_tampa.to_csv('processed_datasets/tampa/reviews_tampa.csv', index = False)
biz_tampa.to_csv('processed_datasets/tampa/restuarants_tampa.csv', index = False)
users_tampa.to_csv('processed_datasets/tampa/users_tampa.csv', index = False)

# %% [markdown]
# ### Creating the Item-User Matrix

# %%
reviews_tampa.drop(columns = ['stars', 'processed_text','sentiment_scores'], axis = 1, inplace=True)
res_tampa = biz_tampa[['business_id', 'name', 'stars']]
users_tampa.drop(columns = ['review_count', 'friends', 'fans'], axis = 1, inplace = True)

# %%
# Merge reviews_philli with users_philli to get user information
merged_df = pd.merge(reviews_tampa, users_tampa, on='user_id', how='left')

# Merge merged_df with res_philli to get restaurant information
merged_df = pd.merge(merged_df, res_tampa, on='business_id', how='left')

# Select relevant columns for the User-Item Ratings matrix
ratings_df = merged_df[['user_id', 'business_id', 'final_rating']]

# Aggregate duplicate entries by taking the mean of the ratings for each combination of user_id and business_id.
ratings_df = ratings_df.groupby(['user_id', 'business_id']).mean().reset_index()

# Pivot the DataFrame to create the User-Item Ratings matrix
ratings_matrix = ratings_df.pivot(index='user_id', columns='business_id', values='final_rating')

ratings_matrix.head()
# Out:
# business_id             --eBbs3HpZYIym5pEw8Qdw  --pDYWb4DzqKdAdrPcxuaA  \
# user_id
# ---2PmXbF47D870stH1jqA                     NaN                     NaN
# --1oZcRo9-QKOtTqREKB6g                     NaN                     NaN
# --238OiSJBDIhfqcSOQyMA                     NaN                     NaN
# --2bpE5vyR-2hAP7sZZ4lA                     NaN                     NaN
# --338aogPBCUUKGRHrB14w                     NaN                     NaN
#
# business_id             --rS-rnOIZxoiDA8yctWpQ  -0oPt7sSKtJG1ysLwV_E9g  \
# user_id
# ---2PmXbF47D870stH1jqA                     NaN                     NaN
# --1oZcRo9-QKOtTqREKB6g                     NaN                     NaN
# --238OiSJBDIhfqcSOQyMA                     NaN                     NaN
# --2bpE5vyR-2hAP7sZZ4lA                     NaN                     NaN
# --338aogPBCUUKGRHrB14w                     NaN                     NaN
#
# business_id             -1oygVebK81K8JEPI6H6Lw  -2CPhK6ik9ZBgFX_F-dkxQ  \
# user_id
# ---2PmXbF47D870stH1jqA                     NaN                     NaN
# --1oZcRo9-QKOtTqREKB6g                     NaN                     NaN
# --238OiSJBDIhfqcSOQyMA                     NaN                     NaN
# --2bpE5vyR-2hAP7sZZ4lA                     NaN                     NaN
# --338aogPBCUUKGRHrB14w                     NaN                     NaN
#
# business_id             -2dvQxx3cYXd5XmFdDDsDA  -2wh7NTLkWEgsrLJvilnFQ  \
# user_id
# ---2PmXbF47D870stH1jqA                     NaN                     NaN
# --1oZcRo9-QKOtTqREKB6g                     NaN                     NaN
# --238OiSJBDIhfqcSOQyMA                     NaN                     NaN
# --2bpE5vyR-2hAP7sZZ4lA                     NaN                     NaN
# --338aogPBCUUKGRHrB14w                     NaN                     NaN
#
# business_id             -34c4hcDPIInTROr8Xtxtw  -361Hc0tlxSYdrH_C3OgzA  ...  \
# user_id                                                                 ...
# ---2PmXbF47D870stH1jqA                     NaN                     NaN  ...
# --1oZcRo9-QKOtTqREKB6g                     NaN                     NaN  ...
# --238OiSJBDIhfqcSOQyMA                     NaN                     NaN  ...
# --2bpE5vyR-2hAP7sZZ4lA                     NaN                     NaN  ...
# --338aogPBCUUKGRHrB14w                     NaN                     NaN  ...
#
# business_id             zjqh_qoBS1BWVSbC51BNjw  znsHfZ2seiCAiO8NGQm8-Q  \
# user_id
# ---2PmXbF47D870stH1jqA                     NaN                     NaN
# --1oZcRo9-QKOtTqREKB6g                     NaN                     NaN
# --238OiSJBDIhfqcSOQyMA                     NaN                     NaN
# --2bpE5vyR-2hAP7sZZ4lA                     NaN                     NaN
# --338aogPBCUUKGRHrB14w                     NaN                     NaN
#
# business_id             zo5Ha3Julfnqy3nUKJYimA  zqdwAXPPIu3pRo0kHA6tVQ  \
# user_id
# ---2PmXbF47D870stH1jqA                     NaN                     NaN
# --1oZcRo9-QKOtTqREKB6g                     NaN                     NaN
# --238OiSJBDIhfqcSOQyMA                     NaN                     NaN
# --2bpE5vyR-2hAP7sZZ4lA                     NaN                     NaN
# --338aogPBCUUKGRHrB14w                     NaN                     NaN
#
# business_id             zr0g9qn3bf_8c4WTeaI9iw  ztnYPn2w0R4lEJL266apzg  \
# user_id
# ---2PmXbF47D870stH1jqA                     NaN                     NaN
# --1oZcRo9-QKOtTqREKB6g                     NaN                     NaN
# --238OiSJBDIhfqcSOQyMA                     NaN                     NaN
# --2bpE5vyR-2hAP7sZZ4lA                     NaN                     NaN
# --338aogPBCUUKGRHrB14w                     NaN                     NaN
#
# business_id             ztppjLmFE25wZOQdJKXAuA  zuObDJ16rxyt5ciCbhKnlA  \
# user_id
# ---2PmXbF47D870stH1jqA                     NaN                     NaN
# --1oZcRo9-QKOtTqREKB6g                     NaN                     NaN
# --238OiSJBDIhfqcSOQyMA                     NaN                     NaN
# --2bpE5vyR-2hAP7sZZ4lA                     NaN                     NaN
# --338aogPBCUUKGRHrB14w                     NaN                     NaN
#
# business_id             zwBvdDWFQpYJE1UMDTlSyw  zxtkbSchfaqY1TpZ7KnmKA
# user_id
# ---2PmXbF47D870stH1jqA                     NaN                     NaN
# --1oZcRo9-QKOtTqREKB6g                     NaN                     NaN
# --238OiSJBDIhfqcSOQyMA                     NaN                     NaN
# --2bpE5vyR-2hAP7sZZ4lA                     NaN                     NaN
# --338aogPBCUUKGRHrB14w                     NaN                     NaN
#
# [5 rows x 3043 columns]

# %%
ratings_matrix.shape
# Out:
# (115757, 3043)

# %%
ratings_matrix.to_csv('processed_datasets/tampa/ratings_matrix_tampa.csv')

# %%
group_by_state = food_biz.groupby('state').agg({'stars':'mean', 'review_count':'sum'}).reset_index()
group_by_state.sort_values('review_count', ascending = False).reset_index()
# Out:
#     index state     stars  review_count
# 0      13    PA  3.540849        933691
# 1       4    FL  3.572522        731186
# 2       9    LA  3.657800        557668
# 3      14    TN  3.472484        408565
# 4      10    MO  3.480798        313708
# 5       8    IN  3.509836        301801
# 6       1    AZ  3.484216        241934
# 7      12    NV  3.576611        235567
# 8       2    CA  3.881114        209237
# 9      11    NJ  3.465351        156617
# 10      6    ID  3.632095         99490
# 11      0    AB  3.539179         62982
# 12      3    DE  3.436728         43720
# 13      7    IL  3.318540         33759
# 14      5    HI  3.500000            17
# 15     15   XMS  4.000000             5

# %%
group_by_FL = food_biz[food_biz['state']=='TN'].groupby('city').agg({'stars':'mean', 'review_count':'sum'}).reset_index()
group_by_FL.sort_values('review_count', ascending = False).reset_index().head(30)
# Out:
#     index              city     stars  review_count
# 0      34         Nashville  3.564888        309102
# 1      12          Franklin  3.539387         34742
# 2       6         Brentwood  3.441989         13007
# 3      18    Hendersonville  3.377907          9006
# 4      42            Smyrna  3.261364          6596
# 5      19         Hermitage  3.099010          5669
# 6       0           Antioch  3.005051          4792
# 7      28      Mount Juliet  3.429348          4647
# 8      27           Madison  3.005952          3243
# 9      15    Goodlettsville  3.325843          2988
# 10     37       Nolensville  3.770270          2157
# 11     13          Gallatin  3.191358          2107
# 12     30        Mt. Juliet  3.614286          1606
# 13     45       White House  3.166667          1404
# 14     29         Mt Juliet  2.843750          1039
# 15     38       Old Hickory  3.592593           966
# 16     23         La Vergne  3.141304           898
# 17     43       Springfield  3.093750           626
# 18     40     Pleasant View  3.195652           568
# 19     10    East Nashville  4.000000           557
# 20      2      Ashland City  3.460000           424
# 21      4          Bellevue  3.066667           382
# 22     21           Joelton  3.875000           297
# 23      5        Berry Hill  4.500000           244
# 24     22  Kingston Springs  3.388889           209
# 25     14     Goodletsville  4.000000           192
# 26     25           Lebanon  2.958333           189
# 27     32         NASHVILLE  2.700000           161
# 28     46      Whites Creek  3.625000           141
# 29      3       Belle Meade  4.000000           139

# %% [markdown]
# # New Orleans

# %%
biz_new_orleans = food_biz[food_biz['city'] == 'New Orleans']
biz_new_orleans.head()
# Out:
#                business_id                        name             address  \
# 14  w_AMNoI1iG9eay7ncmc67w                   River 127    100 Iberville St
# 25  uczmbBk5O3tYhGue13dCDg    New Orleans Spirit Tours     723 St Peter St
# 35  YNjyv0gfOr2g8lbmUpTnKg                 Copper Vine     1001 Poydras St
# 43  TLZ3-eDPLhUzfsWO4ad6Ug  Mahony's Po-Boys & Seafood    901 Iberville St
# 65  hUQ9Z7kQeabvhPOAQOVV1A           Rathbone Mansions  1244 Esplanade Ave
#
#            city state postal_code   latitude  longitude  stars  review_count  \
# 14  New Orleans    LA       70130  29.951359 -90.064672    3.0            12
# 25  New Orleans    LA       70130  29.958431 -90.065173    4.0            38
# 35  New Orleans    LA       70112  29.950647 -90.074427    4.5           350
# 43  New Orleans    LA       70112  29.955415 -90.070062    4.0           382
# 65  New Orleans    LA       70116  29.967055 -90.065828    3.5            67
#
#     ...  GoodForDancing                                         BestNights  \
# 14  ...             NaN                                                NaN
# 25  ...             NaN                                                NaN
# 35  ...           False  {'monday': False, 'tuesday': False, 'friday': ...
# 43  ...             NaN                                                NaN
# 65  ...             NaN                                                NaN
#
#      BYOB Corkage BYOBCorkage AcceptsInsurance RestaurantsCounterService  \
# 14    NaN     NaN         NaN              NaN                       NaN
# 25    NaN     NaN         NaN              NaN                       NaN
# 35    NaN     NaN         NaN              NaN                       NaN
# 43  False     NaN         NaN              NaN                       NaN
# 65    NaN     NaN         NaN              NaN                       NaN
#
#    Open24Hours AgesAllowed DietaryRestrictions
# 14         NaN         NaN                 NaN
# 25         NaN         NaN                 NaN
# 35         NaN         NaN                 NaN
# 43         NaN         NaN                 NaN
# 65         NaN         NaN                 NaN
#
# [5 rows x 51 columns]

# %%
biz_new_orleans.shape
# Out:
# (2699, 51)

# %%
reviews_new_orleans = pd.merge(food_reviews, biz_new_orleans[['business_id']], on = 'business_id', how = 'inner')
reviews_new_orleans.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  6AxgBCNX_PNTOxmbRSwcKQ  r3zeYsv1XFBRA4dJpL78cw  gmjsEdUsKpj9Xxu6pdjH0g
# 1  GdI6HZ34nn3hM2BSHa8X1Q  bMGflZYLUzyOkbOuqKisQA  gmjsEdUsKpj9Xxu6pdjH0g
# 2  GOmxzUrGfC5XGIHfFa0B6Q  ohfjgmu9TiOAur-pVn-zmw  gmjsEdUsKpj9Xxu6pdjH0g
# 3  cEgUTUvkfUUK7hVCbkxU5Q  YWtt5TPZqGfTKA52cVDa-w  gmjsEdUsKpj9Xxu6pdjH0g
# 4  mREBtMW3qRH0vQu23DwNpA  HOzG-IJWXs6C2Lp_Q_RcCw  gmjsEdUsKpj9Xxu6pdjH0g
#
#    stars                                     processed_text
# 0      5  loved tour grabbed groupon price great perfect...
# 1      5  informative took u haunted place planning see ...
# 2      5  tour awesome friend scheduled tour advance gro...
# 3      5  chose tour raving review online voodoo bone la...
# 4      5  friend went voodoo bone lady infamous city dea...

# %%
reviews_new_orleans.shape
# Out:
# (489741, 5)

# %%
reviews_new_orleans['processed_text'] = reviews_new_orleans['processed_text'].astype(str)
reviews_new_orleans['sentiment_scores'] = reviews_new_orleans['processed_text'].apply(get_sentiment_scores)
reviews_new_orleans['final_rating'] = reviews_new_orleans['stars'] + reviews_new_orleans['sentiment_scores']

# %%
users_new_orleans = pd.merge(res_users, reviews_new_orleans[['user_id']], on='user_id', how='inner')
users_new_orleans = users_new_orleans.drop_duplicates(subset='user_id', keep='first')
users_new_orleans.reset_index(drop=True, inplace=True)

# %%
users_new_orleans.shape
# Out:
# (208795, 6)

# %%
reviews_new_orleans.to_csv('processed_datasets/new_orleans/reviews_tampa.csv', index = False)
biz_new_orleans.to_csv('processed_datasets/new_orleans/restuarants_tampa.csv', index = False)
users_new_orleans.to_csv('processed_datasets/new_orleans/users_tampa.csv', index = False)

# %% [markdown]
# ### Creating the Item-User Matrix

# %%
reviews_new_orleans.drop(columns = ['stars', 'processed_text','sentiment_scores'], axis = 1, inplace=True)
res_new_orleans = biz_new_orleans[['business_id', 'name', 'stars']]
users_new_orleans.drop(columns = ['review_count', 'friends', 'fans'], axis = 1, inplace = True)

# %%
# Merge reviews_philli with users_philli to get user information
merged_df = pd.merge(reviews_new_orleans, users_new_orleans, on='user_id', how='left')

# Merge merged_df with res_philli to get restaurant information
merged_df = pd.merge(merged_df, res_new_orleans, on='business_id', how='left')

# Select relevant columns for the User-Item Ratings matrix
ratings_df = merged_df[['user_id', 'business_id', 'final_rating']]

# Aggregate duplicate entries by taking the mean of the ratings for each combination of user_id and business_id.
ratings_df = ratings_df.groupby(['user_id', 'business_id']).mean().reset_index()

# Pivot the DataFrame to create the User-Item Ratings matrix
ratings_matrix = ratings_df.pivot(index='user_id', columns='business_id', values='final_rating')

ratings_matrix.head()
# Out:
# business_id             --x_BmZbxzK_nx_GHBaRVw  --zb12mw2YK-7j6UaHzm8w  \
# user_id
# ---UgP94gokyCDuB5zUssA                     NaN                     NaN
# --1FFSF8N5TtSfzH7We4NA                     NaN                     NaN
# --1orhUoGFSdHXsoxqQc8g                     NaN                     NaN
# --3PldvWEZ_bhLNsyrAtgA                     NaN                     NaN
# --3WaS23LcIXtxyFULJHTA                     NaN                     NaN
#
# business_id             -0__F9fnKt8uioCKztF5Ww  -0ltw8--HLuulPyOSspqAQ  \
# user_id
# ---UgP94gokyCDuB5zUssA                     NaN                     NaN
# --1FFSF8N5TtSfzH7We4NA                     NaN                     NaN
# --1orhUoGFSdHXsoxqQc8g                     NaN                     NaN
# --3PldvWEZ_bhLNsyrAtgA                     NaN                     NaN
# --3WaS23LcIXtxyFULJHTA                     NaN                     NaN
#
# business_id             -1XSzguS6XLN-V6MVZMg2A  -4x3pVUUsfWmKEilWKsOZQ  \
# user_id
# ---UgP94gokyCDuB5zUssA                     NaN                     NaN
# --1FFSF8N5TtSfzH7We4NA                     NaN                     NaN
# --1orhUoGFSdHXsoxqQc8g                     NaN                     NaN
# --3PldvWEZ_bhLNsyrAtgA                     NaN                     NaN
# --3WaS23LcIXtxyFULJHTA                     NaN                     NaN
#
# business_id             -86Z04IBKxhEQ17rCOkn8g  -9ZNA22YhFlvTdLDYjvNdA  \
# user_id
# ---UgP94gokyCDuB5zUssA                     NaN                     NaN
# --1FFSF8N5TtSfzH7We4NA                     NaN                     NaN
# --1orhUoGFSdHXsoxqQc8g                     NaN                     NaN
# --3PldvWEZ_bhLNsyrAtgA                     NaN                     NaN
# --3WaS23LcIXtxyFULJHTA                     NaN                     NaN
#
# business_id             -9yzQQ0d_rcOD2CzdTNO_Q  -A2OLubXDsMRPNN7LqohPA  ...  \
# user_id                                                                 ...
# ---UgP94gokyCDuB5zUssA                     NaN                     NaN  ...
# --1FFSF8N5TtSfzH7We4NA                     NaN                     NaN  ...
# --1orhUoGFSdHXsoxqQc8g                     NaN                     NaN  ...
# --3PldvWEZ_bhLNsyrAtgA                     NaN                     NaN  ...
# --3WaS23LcIXtxyFULJHTA                     NaN                     NaN  ...
#
# business_id             znmW7djuEJjlMI0hw-utEw  zqGEI72ihSB6uipAlE9opQ  \
# user_id
# ---UgP94gokyCDuB5zUssA                     NaN                     NaN
# --1FFSF8N5TtSfzH7We4NA                     NaN                     NaN
# --1orhUoGFSdHXsoxqQc8g                     NaN                     NaN
# --3PldvWEZ_bhLNsyrAtgA                     NaN                     NaN
# --3WaS23LcIXtxyFULJHTA                     NaN                     NaN
#
# business_id             zqMftGuxwL8mwQvy2nq9Zg  zr7vspTJPNgxP-j90bc_wg  \
# user_id
# ---UgP94gokyCDuB5zUssA                     NaN                     NaN
# --1FFSF8N5TtSfzH7We4NA                     NaN                     NaN
# --1orhUoGFSdHXsoxqQc8g                     NaN                     NaN
# --3PldvWEZ_bhLNsyrAtgA                     NaN                     NaN
# --3WaS23LcIXtxyFULJHTA                     NaN                     NaN
#
# business_id             ztcOE7NN0WdleNOCbje8ng  zvGNZF827KyzLupKiG4Xtw  \
# user_id
# ---UgP94gokyCDuB5zUssA                     NaN                     NaN
# --1FFSF8N5TtSfzH7We4NA                     NaN                     NaN
# --1orhUoGFSdHXsoxqQc8g                     NaN                     NaN
# --3PldvWEZ_bhLNsyrAtgA                     NaN                     NaN
# --3WaS23LcIXtxyFULJHTA                     NaN                     NaN
#
# business_id             zwe9H6Xxqb1_E09A20Ptgg  zxIF-bnaJ-eKIsznB7yu7A  \
# user_id
# ---UgP94gokyCDuB5zUssA                     NaN                     NaN
# --1FFSF8N5TtSfzH7We4NA                     NaN                     NaN
# --1orhUoGFSdHXsoxqQc8g                     NaN                     NaN
# --3PldvWEZ_bhLNsyrAtgA                     NaN                     NaN
# --3WaS23LcIXtxyFULJHTA                     NaN                     NaN
#
# business_id             zzbZtgPYZS8sTIWQH6DwEw  zznZqH9CiAznbkV6fXyHWA
# user_id
# ---UgP94gokyCDuB5zUssA                     NaN                     NaN
# --1FFSF8N5TtSfzH7We4NA                     NaN                     NaN
# --1orhUoGFSdHXsoxqQc8g                     NaN                     NaN
# --3PldvWEZ_bhLNsyrAtgA                     NaN                     NaN
# --3WaS23LcIXtxyFULJHTA                     NaN                     NaN
#
# [5 rows x 2699 columns]

# %%
ratings_matrix.shape
# Out:
# (208796, 2699)

# %%
ratings_matrix.to_csv('processed_datasets/new_orleans/ratings_matrix_new_orleans.csv')

# %% [markdown]
# # Nashville
